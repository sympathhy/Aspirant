# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Dlya_laby.csv')
df.drop(['Адрес', 'index'], axis = 1, inplace = True)
df.tail()
# Out:
#        Количество транзакций  Количество исходящих транзакций  \
# 41693                      2                                1
# 41694                      2                                1
# 41695                      2                                1
# 41696                      2                                1
# 41697                      2                                1
#
#        Количество входящих транзакций  Среднее количество транзакций в день  \
# 41693                               1                              0.001279
# 41694                               1                              0.001279
# 41695                               1                              0.001279
# 41696                               1                              0.001280
# 41697                               1                              0.001280
#
#        Средний размер транзакции  Медиана размера транзакций  \
# 41693                 98667550.0                  98667550.0
# 41694                 39089823.0                  39089823.0
# 41695                100000000.0                 100000000.0
# 41696                 99982146.0                  99982146.0
# 41697                 44203306.0                  44203306.0
#
#        Дисперсия размера транзакций  Средний размер исходящей транзакции  \
# 41693                           0.0                           98667550.0
# 41694                           0.0                           39089823.0
# 41695                           0.0                          100000000.0
# 41696                           0.0                           99982146.0
# 41697                           0.0                           44203306.0
#
#        Средний размер входящей транзакции  \
# 41693                          98667550.0
# 41694                          39089823.0
# 41695                         100000000.0
# 41696                          99982146.0
# 41697                          44203306.0
#
#        Медиана размера исходящей транзакций  ...  nкnв  1к1и  1к2и  1кnи  \
# 41693                            98667550.0  ...   0.0   0.0   0.0   0.0
# 41694                            39089823.0  ...   0.0   0.0   1.0   0.0
# 41695                           100000000.0  ...   0.0   1.0   0.0   0.0
# 41696                            99982146.0  ...   0.0   0.0   0.0   0.0
# 41697                            44203306.0  ...   0.0   0.0   1.0   0.0
#
#        nк1и  nк2и  nкnи  max_in  max_out  default
# 41693   0.0   1.0   0.0       5        5        0
# 41694   0.0   0.0   0.0       2        2        0
# 41695   0.0   0.0   0.0       3        1        0
# 41696   0.0   1.0   0.0       2        5        0
# 41697   0.0   0.0   0.0       5        2        0
#
# [5 rows x 54 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41698 entries, 0 to 41697
# Data columns (total 54 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Количество транзакций                    41698 non-null  int64
#  1   Количество исходящих транзакций          41698 non-null  int64
#  2   Количество входящих транзакций           41698 non-null  int64
#  3   Среднее количество транзакций в день     41698 non-null  float64
#  4   Средний размер транзакции                41698 non-null  float64
#  5   Медиана размера транзакций               41698 non-null  float64
#  6   Дисперсия размера транзакций             41698 non-null  float64
#  7   Средний размер исходящей транзакции      41698 non-null  float64
#  8   Средний размер входящей транзакции       41698 non-null  float64
#  9   Медиана размера исходящей транзакций     41698 non-null  float64
#  10  Медиана размера входящей транзакций      41698 non-null  float64
#  11  Дисперсия размера исходящей транзакции   41698 non-null  float64
#  12  Дисперсия размера входящей транзакции    41698 non-null  float64
#  13  Среднее количество выходов в транзакции  41698 non-null  float64
#  14  Среднее количество входов в транзакции   41698 non-null  float64
#  15  Медиана количества выходов транзакций    41698 non-null  float64
#  16  Медиана количества входов транзакций     41698 non-null  float64
#  17  Дисперсия количества выходов транзакций  41698 non-null  float64
#  18  Дисперсия количества входов транзакций   41698 non-null  float64
#  19  Средний размер выходов в транзакциях     41698 non-null  float64
#  20  Средний размер входов в транзакциях      41698 non-null  float64
#  21  Медиана размера выходов в транзакциях    41698 non-null  float64
#  22  Медиана размера входов в транзакциях     41698 non-null  float64
#  23  Дисперсия размера выходов в транзакциях  41698 non-null  float64
#  24  Дисперсия размера входов в транзакциях   41698 non-null  float64
#  25  Всего пришло                             41698 non-null  int64
#  26  Всего ушло                               41698 non-null  int64
#  27  Текущий баланс кошелька                  41698 non-null  int64
#  28  Майнинг                                  41698 non-null  int64
#  29  1к1                                      41698 non-null  float64
#  30  1к2                                      41698 non-null  float64
#  31  1кn                                      41698 non-null  float64
#  32  nк1                                      41698 non-null  float64
#  33  nк2                                      41698 non-null  float64
#  34  nкn                                      41698 non-null  float64
#  35  Количество транзакций классы             41698 non-null  int64
#  36  Всего пришло классы                      41698 non-null  int64
#  37  Процент входящих транзакций              41698 non-null  float64
#  38  Всего ушло в процентах от прихода        41698 non-null  float64
#  39  1к1в                                     41698 non-null  float64
#  40  1к2в                                     41698 non-null  float64
#  41  1кnв                                     41698 non-null  float64
#  42  nк1в                                     41698 non-null  float64
#  43  nк2в                                     41698 non-null  float64
#  44  nкnв                                     41698 non-null  float64
#  45  1к1и                                     41698 non-null  float64
#  46  1к2и                                     41698 non-null  float64
#  47  1кnи                                     41698 non-null  float64
#  48  nк1и                                     41698 non-null  float64
#  49  nк2и                                     41698 non-null  float64
#  50  nкnи                                     41698 non-null  float64
#  51  max_in                                   41698 non-null  int64
#  52  max_out                                  41698 non-null  int64
#  53  default                                  41698 non-null  int64
# dtypes: float64(42), int64(12)
# memory usage: 17.2 MB

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('default', axis = 1), df['default'], test_size = 0.2)

# %%
lg = LogisticRegression(penalty = 'l2', solver = 'saga')
lg.fit(X_train, y_train)
lg.score(X_test, y_test)
# Out:
# C:\anacond\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 0.505515587529976

# %%
dtc = DecisionTreeClassifier(max_depth = 6)
dtc.fit(X_train, y_train)
dtc.score(X_test, y_test)
tree.plot_tree(dtc)
# Out:
# [Text(0.48936170212765956, 0.9285714285714286, 'x[46] <= 0.028\ngini = 0.5\nsamples = 33358\nvalue = [16633, 16725]'),
#  Text(0.2553191489361702, 0.7857142857142857, 'x[3] <= 0.001\ngini = 0.445\nsamples = 24603\nvalue = [8231, 16372]'),
#  Text(0.14361702127659576, 0.6428571428571429, 'x[18] <= 370.625\ngini = 0.306\nsamples = 5350\nvalue = [4341, 1009]'),
#  Text(0.0851063829787234, 0.5, 'x[18] <= 39.903\ngini = 0.102\nsamples = 4374\nvalue = [4137, 237]'),
#  Text(0.0425531914893617, 0.35714285714285715, 'x[18] <= 7.625\ngini = 0.039\nsamples = 3782\nvalue = [3706, 76]'),
#  Text(0.02127659574468085, 0.21428571428571427, 'x[3] <= 0.001\ngini = 0.018\nsamples = 3163\nvalue = [3134, 29]'),
#  Text(0.010638297872340425, 0.07142857142857142, 'gini = 0.016\nsamples = 3137\nvalue = [3111, 26]'),
#  Text(0.031914893617021274, 0.07142857142857142, 'gini = 0.204\nsamples = 26\nvalue = [23, 3]'),
#  Text(0.06382978723404255, 0.21428571428571427, 'x[3] <= 0.001\ngini = 0.14\nsamples = 619\nvalue = [572, 47]'),
#  Text(0.05319148936170213, 0.07142857142857142, 'gini = 0.31\nsamples = 193\nvalue = [156, 37]'),
#  Text(0.07446808510638298, 0.07142857142857142, 'gini = 0.046\nsamples = 426\nvalue = [416, 10]'),
#  Text(0.1276595744680851, 0.35714285714285715, 'x[3] <= 0.001\ngini = 0.396\nsamples = 592\nvalue = [431, 161]'),
#  Text(0.10638297872340426, 0.21428571428571427, 'x[3] <= 0.001\ngini = 0.484\nsamples = 254\nvalue = [104, 150]'),
#  Text(0.09574468085106383, 0.07142857142857142, 'gini = 0.0\nsamples = 87\nvalue = [87, 0]'),
#  Text(0.11702127659574468, 0.07142857142857142, 'gini = 0.183\nsamples = 167\nvalue = [17, 150]'),
#  Text(0.14893617021276595, 0.21428571428571427, 'x[14] <= 93.25\ngini = 0.063\nsamples = 338\nvalue = [327, 11]'),
#  Text(0.13829787234042554, 0.07142857142857142, 'gini = 0.052\nsamples = 336\nvalue = [327, 9]'),
#  Text(0.1595744680851064, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.20212765957446807, 0.5, 'x[3] <= 0.001\ngini = 0.331\nsamples = 976\nvalue = [204, 772]'),
#  Text(0.19148936170212766, 0.35714285714285715, 'gini = 0.0\nsamples = 77\nvalue = [77, 0]'),
#  Text(0.2127659574468085, 0.35714285714285715, 'x[3] <= 0.001\ngini = 0.243\nsamples = 899\nvalue = [127, 772]'),
#  Text(0.19148936170212766, 0.21428571428571427, 'x[34] <= 0.75\ngini = 0.059\nsamples = 756\nvalue = [23, 733]'),
#  Text(0.18085106382978725, 0.07142857142857142, 'gini = 0.037\nsamples = 744\nvalue = [14, 730]'),
#  Text(0.20212765957446807, 0.07142857142857142, 'gini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.23404255319148937, 0.21428571428571427, 'x[22] <= 286678784.0\ngini = 0.397\nsamples = 143\nvalue = [104, 39]'),
#  Text(0.22340425531914893, 0.07142857142857142, 'gini = 0.021\nsamples = 95\nvalue = [94, 1]'),
#  Text(0.24468085106382978, 0.07142857142857142, 'gini = 0.33\nsamples = 48\nvalue = [10, 38]'),
#  Text(0.3670212765957447, 0.6428571428571429, 'x[3] <= 0.001\ngini = 0.322\nsamples = 19253\nvalue = [3890, 15363]'),
#  Text(0.30851063829787234, 0.5, 'x[52] <= 5.5\ngini = 0.158\nsamples = 13102\nvalue = [1133, 11969]'),
#  Text(0.2978723404255319, 0.35714285714285715, 'x[47] <= 0.5\ngini = 0.137\nsamples = 12925\nvalue = [956, 11969]'),
#  Text(0.2765957446808511, 0.21428571428571427, 'x[32] <= 0.125\ngini = 0.121\nsamples = 12796\nvalue = [829, 11967]'),
#  Text(0.26595744680851063, 0.07142857142857142, 'gini = 0.101\nsamples = 12590\nvalue = [675, 11915]'),
#  Text(0.2872340425531915, 0.07142857142857142, 'gini = 0.377\nsamples = 206\nvalue = [154, 52]'),
#  Text(0.3191489361702128, 0.21428571428571427, 'x[24] <= 1081387664.0\ngini = 0.031\nsamples = 129\nvalue = [127, 2]'),
#  Text(0.30851063829787234, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.32978723404255317, 0.07142857142857142, 'gini = 0.0\nsamples = 127\nvalue = [127, 0]'),
#  Text(0.3191489361702128, 0.35714285714285715, 'gini = 0.0\nsamples = 177\nvalue = [177, 0]'),
#  Text(0.425531914893617, 0.5, 'x[2] <= 1.5\ngini = 0.495\nsamples = 6151\nvalue = [2757, 3394]'),
#  Text(0.3829787234042553, 0.35714285714285715, 'x[45] <= 0.5\ngini = 0.209\nsamples = 1005\nvalue = [886, 119]'),
#  Text(0.3617021276595745, 0.21428571428571427, 'x[11] <= 2.786597879978918e+18\ngini = 0.007\nsamples = 833\nvalue = [830, 3]'),
#  Text(0.35106382978723405, 0.07142857142857142, 'gini = 0.005\nsamples = 832\nvalue = [830, 2]'),
#  Text(0.3723404255319149, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.40425531914893614, 0.21428571428571427, 'x[3] <= 0.001\ngini = 0.439\nsamples = 172\nvalue = [56, 116]'),
#  Text(0.39361702127659576, 0.07142857142857142, 'gini = 0.079\nsamples = 121\nvalue = [5, 116]'),
#  Text(0.4148936170212766, 0.07142857142857142, 'gini = 0.0\nsamples = 51\nvalue = [51, 0]'),
#  Text(0.46808510638297873, 0.35714285714285715, 'x[13] <= 4.376\ngini = 0.463\nsamples = 5146\nvalue = [1871, 3275]'),
#  Text(0.44680851063829785, 0.21428571428571427, 'x[18] <= 6842.278\ngini = 0.385\nsamples = 3758\nvalue = [977, 2781]'),
#  Text(0.43617021276595747, 0.07142857142857142, 'gini = 0.344\nsamples = 3469\nvalue = [767, 2702]'),
#  Text(0.4574468085106383, 0.07142857142857142, 'gini = 0.397\nsamples = 289\nvalue = [210, 79]'),
#  Text(0.48936170212765956, 0.21428571428571427, 'x[50] <= 0.531\ngini = 0.458\nsamples = 1388\nvalue = [894, 494]'),
#  Text(0.4787234042553192, 0.07142857142857142, 'gini = 0.498\nsamples = 1009\nvalue = [540, 469]'),
#  Text(0.5, 0.07142857142857142, 'gini = 0.123\nsamples = 379\nvalue = [354, 25]'),
#  Text(0.723404255319149, 0.7857142857142857, 'x[50] <= 0.032\ngini = 0.077\nsamples = 8755\nvalue = [8402, 353]'),
#  Text(0.5877659574468085, 0.6428571428571429, 'x[3] <= 0.001\ngini = 0.047\nsamples = 8437\nvalue = [8232, 205]'),
#  Text(0.5425531914893617, 0.5, 'x[7] <= 15288153.5\ngini = 0.006\nsamples = 6492\nvalue = [6472, 20]'),
#  Text(0.5319148936170213, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5531914893617021, 0.35714285714285715, 'x[29] <= 0.292\ngini = 0.006\nsamples = 6491\nvalue = [6472, 19]'),
#  Text(0.5319148936170213, 0.21428571428571427, 'x[11] <= 2.0372162216977865e+20\ngini = 0.004\nsamples = 6404\nvalue = [6390, 14]'),
#  Text(0.5212765957446809, 0.07142857142857142, 'gini = 0.004\nsamples = 6402\nvalue = [6389, 13]'),
#  Text(0.5425531914893617, 0.07142857142857142, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.574468085106383, 0.21428571428571427, 'x[23] <= 4195183662989312.0\ngini = 0.108\nsamples = 87\nvalue = [82, 5]'),
#  Text(0.5638297872340425, 0.07142857142857142, 'gini = 0.206\nsamples = 43\nvalue = [38, 5]'),
#  Text(0.5851063829787234, 0.07142857142857142, 'gini = 0.0\nsamples = 44\nvalue = [44, 0]'),
#  Text(0.6329787234042553, 0.5, 'x[10] <= 5490.0\ngini = 0.172\nsamples = 1945\nvalue = [1760, 185]'),
#  Text(0.6063829787234043, 0.35714285714285715, 'x[24] <= 2281272281923584.0\ngini = 0.483\nsamples = 22\nvalue = [9, 13]'),
#  Text(0.5957446808510638, 0.21428571428571427, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.6170212765957447, 0.21428571428571427, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.6595744680851063, 0.35714285714285715, 'x[48] <= 0.0\ngini = 0.163\nsamples = 1923\nvalue = [1751, 172]'),
#  Text(0.6382978723404256, 0.21428571428571427, 'x[14] <= 25.694\ngini = 0.245\nsamples = 1020\nvalue = [874, 146]'),
#  Text(0.6276595744680851, 0.07142857142857142, 'gini = 0.21\nsamples = 958\nvalue = [844, 114]'),
#  Text(0.648936170212766, 0.07142857142857142, 'gini = 0.499\nsamples = 62\nvalue = [30, 32]'),
#  Text(0.6808510638297872, 0.21428571428571427, 'x[7] <= 3969184.75\ngini = 0.056\nsamples = 903\nvalue = [877, 26]'),
#  Text(0.6702127659574468, 0.07142857142857142, 'gini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.6914893617021277, 0.07142857142857142, 'gini = 0.046\nsamples = 892\nvalue = [871, 21]'),
#  Text(0.8590425531914894, 0.6428571428571429, 'x[32] <= 0.053\ngini = 0.498\nsamples = 318\nvalue = [170, 148]'),
#  Text(0.7872340425531915, 0.5, 'x[21] <= 24657000.0\ngini = 0.333\nsamples = 166\nvalue = [131, 35]'),
#  Text(0.7446808510638298, 0.35714285714285715, 'x[48] <= 0.026\ngini = 0.13\nsamples = 100\nvalue = [93, 7]'),
#  Text(0.723404255319149, 0.21428571428571427, 'x[21] <= 20226468.0\ngini = 0.024\nsamples = 84\nvalue = [83, 1]'),
#  Text(0.7127659574468085, 0.07142857142857142, 'gini = 0.0\nsamples = 74\nvalue = [74, 0]'),
#  Text(0.7340425531914894, 0.07142857142857142, 'gini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.7659574468085106, 0.21428571428571427, 'x[32] <= 0.034\ngini = 0.469\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.7553191489361702, 0.07142857142857142, 'gini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.776595744680851, 0.07142857142857142, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.8297872340425532, 0.35714285714285715, 'x[47] <= 0.027\ngini = 0.489\nsamples = 66\nvalue = [38, 28]'),
#  Text(0.8085106382978723, 0.21428571428571427, 'x[39] <= 0.031\ngini = 0.472\nsamples = 42\nvalue = [16, 26]'),
#  Text(0.7978723404255319, 0.07142857142857142, 'gini = 0.497\nsamples = 28\nvalue = [15, 13]'),
#  Text(0.8191489361702128, 0.07142857142857142, 'gini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.851063829787234, 0.21428571428571427, 'x[43] <= 0.764\ngini = 0.153\nsamples = 24\nvalue = [22, 2]'),
#  Text(0.8404255319148937, 0.07142857142857142, 'gini = 0.083\nsamples = 23\nvalue = [22, 1]'),
#  Text(0.8617021276595744, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9308510638297872, 0.5, 'x[18] <= 578.164\ngini = 0.381\nsamples = 152\nvalue = [39, 113]'),
#  Text(0.9042553191489362, 0.35714285714285715, 'x[46] <= 0.461\ngini = 0.337\nsamples = 28\nvalue = [22, 6]'),
#  Text(0.8936170212765957, 0.21428571428571427, 'x[26] <= 344686160.0\ngini = 0.211\nsamples = 25\nvalue = [22, 3]'),
#  Text(0.8829787234042553, 0.07142857142857142, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9042553191489362, 0.07142857142857142, 'gini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.9148936170212766, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9574468085106383, 0.35714285714285715, 'x[20] <= 58605768.0\ngini = 0.237\nsamples = 124\nvalue = [17, 107]'),
#  Text(0.9361702127659575, 0.21428571428571427, 'x[50] <= 0.296\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.925531914893617, 0.07142857142857142, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.9468085106382979, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9787234042553191, 0.21428571428571427, 'x[47] <= 0.077\ngini = 0.172\nsamples = 116\nvalue = [11, 105]'),
#  Text(0.9680851063829787, 0.07142857142857142, 'gini = 0.12\nsamples = 109\nvalue = [7, 102]'),
#  Text(0.9893617021276596, 0.07142857142857142, 'gini = 0.49\nsamples = 7\nvalue = [4, 3]')]

# %%
neigh = KNeighborsClassifier()
param = {'n_neighbors':range(3, 10), 'weights':['uniform', 'distance']}
gsv = GridSearchCV(neigh, param_grid = param)
gsv.fit(X_train, y_train)
# Out:
# 0.7386091127098321

# %%
gsv.best_estimator_.score(X_test, y_test)

# %%
rf = RandomForestClassifier()
param = {'n_estimators':range(150, 350, 50), 'criretion':['entropy', 'gini', 'log_loss'], 'max_depth': range(5, 8)}
gsv = GridSearchCV(rf, param_grid = param)
gsv.fit(X_train, y_train)

# %%
gsv.best_estimator_.score(X_test, y_test)
